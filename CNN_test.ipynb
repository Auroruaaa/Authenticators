# %%
import numpy as np
import mne
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.optimizers import RMSprop


def load_physionet_data(subject_ids, channels):
    raw_files = []
    for subject in subject_ids:
        raw = mne.io.read_raw_edf(f'files/S{subject:03d}/S{subject:03d}R01.edf', preload=True)
        raw.pick_channels(channels)
        raw_files.append(raw)
    return raw_files


def preprocess_data(raw, T=160, delta=4, Delta=8):

    data = raw.get_data().T 
    scaler = MinMaxScaler()
    normalized_data = scaler.fit_transform(data)
    

    n_samples = normalized_data.shape[0]
    windows = []
    for start in range(0, n_samples - T + 1, delta):
        window = normalized_data[start:start+T, :]
        windows.append(window)
    return np.array(windows)


def augment_data(windows, Gamma=236, Delta=8):
    augmented = []
    for i in range(0, len(windows) - Gamma + 1, Delta):
        augmented.append(windows[i:i+Gamma])
    return np.array(augmented)


channels = ['Oz..', 'T7..', 'Cz..']
alpha_subjects = list(range(1, 91))
raw_data = load_physionet_data(alpha_subjects, channels)
windows = [preprocess_data(raw) for raw in raw_data]
augmented = [augment_data(win) for win in windows]
X_train = np.concatenate(augmented, axis=0)
y_train = np.repeat(np.arange(len(alpha_subjects)), [len(a) for a in augmented])
# Out:
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S001/S001R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S002/S002R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S003/S003R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S004/S004R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S005/S005R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S006/S006R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S007/S007R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S008/S008R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S009/S009R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S010/S010R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S011/S011R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S012/S012R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S013/S013R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S014/S014R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9599  =      0.000 ...    59.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S015/S015R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S016/S016R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S017/S017R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S018/S018R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S019/S019R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S020/S020R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S021/S021R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S022/S022R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S023/S023R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S024/S024R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S025/S025R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S026/S026R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S027/S027R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S028/S028R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S029/S029R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S030/S030R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S031/S031R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S032/S032R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S033/S033R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S034/S034R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S035/S035R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S036/S036R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S037/S037R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S038/S038R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S039/S039R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S040/S040R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S041/S041R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S042/S042R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S043/S043R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S044/S044R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S045/S045R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S046/S046R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S047/S047R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S048/S048R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S049/S049R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S050/S050R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S051/S051R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9599  =      0.000 ...    59.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S052/S052R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S053/S053R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S054/S054R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S055/S055R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S056/S056R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S057/S057R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S058/S058R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S059/S059R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S060/S060R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S061/S061R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S062/S062R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S063/S063R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S064/S064R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S065/S065R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S066/S066R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S067/S067R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S068/S068R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S069/S069R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9599  =      0.000 ...    59.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S070/S070R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S071/S071R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S072/S072R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S073/S073R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S074/S074R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S075/S075R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S076/S076R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S077/S077R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S078/S078R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S079/S079R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S080/S080R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S081/S081R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S082/S082R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S083/S083R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S084/S084R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S085/S085R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S086/S086R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S087/S087R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S088/S088R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S089/S089R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Extracting EDF parameters from /Users/kris/Desktop/COGS189/COGS189_FinalProject/files/S090/S090R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def build_classification_model(input_shape, n_classes):
    inputs = Input(shape=input_shape)
    x = Conv2D(128, (3,3), activation='relu')(inputs)
    x = MaxPooling2D((2,2))(x)
    x = Conv2D(256, (3,3), activation='relu')(x)
    x = MaxPooling2D((2,2))(x)
    x = Conv2D(512, (3,3), activation='relu')(x)
    x = Flatten()(x)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.25)(x)
    outputs = Dense(n_classes, activation='softmax')(x)
    
    model = Model(inputs, outputs)
    model.compile(optimizer=RMSprop(0.0001), 
                  loss='sparse_categorical_crossentropy', 
                  metrics=['accuracy'])
    return model


model = build_classification_model((20, 160, 3), len(alpha_subjects))
model.fit(X_train, y_train, epochs=30, batch_size=64)


fingerprint_model = Model(inputs=model.input, outputs=model.layers[-4].output)

# %%
from sklearn.metrics import pairwise_distances

def enroll_user(eeg_sample):
    fingerprint = fingerprint_model.predict(eeg_sample)
    return fingerprint.mean(axis=0) 

def authenticate(claimed_fingerprint, new_sample, threshold=0.275):
    new_fingerprint = fingerprint_model.predict(new_sample).mean(axis=0)
    distance = pairwise_distances([claimed_fingerprint], [new_fingerprint], metric='cosine')[0][0]
    return distance <= threshold


user_sample = X_train[0]
stored_fingerprint = enroll_user(user_sample)


new_sample = X_train[1]
is_authenticated = authenticate(stored_fingerprint, new_sample)
print("Authentication result:", is_authenticated)
